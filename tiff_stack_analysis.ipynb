# %%
from PIL import Image
from matplotlib.pyplot import imshow
import numpy as np
import os

# %%
# %matplotlib inline

# %%
img = Image.open('data/IGF1R_IR_DoubleKO_control_081215B_001.tif')

# %%
def count_images_in_file(path):
    count = 0
    img = Image.open(path)
    while True:
        try:   
            img.seek(count)
        except EOFError:
            break       
        count += 1          

    print(count)
    return count

# %%
imshow(np.array(img))

# %%
count = count_images_in_file('data/IGF1R_IR_DoubleKO_control_081215B_001.tif')
# Out:
# 8

# %%
a = [np.array([[1,2,3,4,5];[4,5,6,7,8]),np.array([1,2,3,4,5])]
# Out:
#   File "<ipython-input-43-c78a3fb32bb2>", line 1
#     a = [np.array([[1,2,3,4,5];[4,5,6,7,8]),np.array([1,2,3,4,5])]
#                               ^
# SyntaxError: invalid syntax

# %%
a = []
a.append(np.array([[1,2,3,4,5],
                   [4,5,6,7,8]]))
a.append(np.array([[1,2,3,4,5]]))

# %%
np.concatenate(a,axis=0)
# Out:
# array([[1, 2, 3, 4, 5],
#        [4, 5, 6, 7, 8],
#        [1, 2, 3, 4, 5]])
